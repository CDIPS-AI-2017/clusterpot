# %%
import json
import spacy
import requests
import textacy
from spacy.symbols import nsubj, VERB, dobj
from pprint import pprint

# %%
nlp = spacy.load('en')

# %%
r = requests.get('http://harrypotter.wikia.com/api/v1/Articles/Top')
hp_id = [it['id'] for it in json.loads(r.content)['items'] if it['title'] == 'Harry Potter'][0]
r = requests.get('http://harrypotter.wikia.com/api/v1/Articles/AsSimpleJson', params={'id': hp_id})
wiki = json.loads(r.content)

# %%
def paragraph_info(doc):
    """
    Return a dictionary of the people, places, activities, things, and times mentioned in the text
    """
    entities = {'people': {},
                'places': {},
                'things': {},
                'times': {},
                'verbs': {}}
    for ent in doc.ents:
        if ent.label_ in ('CARDINAL', 'ORDINAL'):
            continue
        elif ent.label_ == 'PERSON':
            try:
                entities['people'][ent.lemma_] += 1
            except KeyError:
                entities['people'][ent.lemma_] = 1
        elif ent.label_ in ('GPE', 'LOC'):
            try:
                entities['places'][ent.lemma_] += 1
            except KeyError:
                entities['places'][ent.lemma_] = 1
        elif ent.label_ in ('ORG', 'WORK_OF_ART', 'LAW', 'NORP', 'FAC', 'PRODUCT'):
            try:
                entities['things'][ent.lemma_] += 1
            except KeyError:
                entities['things'][ent.lemma_] = 1
        elif ent.label_ in ('DATE', 'TIME', 'EVENT'):
            try:
                entities['times'][ent.lemma_] += 1
            except KeyError:
                entities['times'][ent.lemma_] = 1
    for verb in textacy.spacy_utils.get_main_verbs_of_sent(doc):
        try:
            entities['verbs'][verb.lemma_] += 1
        except KeyError:
            entities['verbs'][verb.lemma_] = 1
    return entities

# %%
for section in wiki['sections'][:-10]:
    print
    print section['title']
    print
    for unit in section['content']:
        if unit['type'] != 'paragraph':
            continue
        doc = nlp(unit['text'])
        pprint(paragraph_info(doc))
# Out:
# Harry Potter
#
# {'people': {u'evans': 1,
#             u'harry': 4,
#             u'harry james potter': 1,
#             u'james': 1,
#             u'lily potter': 1,
#             u'lord voldemort': 1,
#             u'voldemort': 1},
#  'places': {u'voldemort': 1},
#  'things': {u'boy who lived': 1},
#  'times': {u'1980': 1,
#            u'31 july': 1,
#            u'a year and three month old': 1,
#            u'the end of july of 1980': 1,
#            u'the end of the': 1},
#  'verbs': {u'attack': 1,
#            u'be': 4,
#            u'bear': 1,
#            u'circumvent': 1,
#            u'defeat': 1,
#            u'know': 1,
#            u'lead': 1,
#            u'mark': 1,
#            u'murder': 2,
#            u'protect': 1,
#            u'prove': 1,
#            u'state': 1,
#            u'try': 2,
#            u'vanquish': 1}}
# {'people': {u'albus dumbledore': 1,
#             u'harry': 1,
#             u'lily': 1,
#             u'lord voldemort': 1,
#             u'petunia dursley': 1},
#  'places': {},
#  'things': {u'bond of blood': 1,
#             u'hogwarts school of witchcraft and': 1,
#             u'muggle': 1},
#  'times': {},
#  'verbs': {u'arrive': 1,
#            u'be': 2,
#            u'become': 1,
#            u'have': 1,
#            u'know': 1,
#            u'place': 1,
#            u'protect': 2,
#            u'raise': 1,
#            u'remain': 1}}
# {'people': {u'cedric diggory': 1,
#             u'ginny weasley': 1,
#             u'harry': 4,
#             u'hermione granger': 1,
#             u'quidditch seeker': 1,
#             u'ron': 1,
#             u'ron weasley': 1,
#             u"salazar slytherin 's": 1,
#             u'sirius black': 1,
#             u'stone': 1},
#  'places': {u'hogwarts': 1, u'patronus': 1, u'voldemort': 1},
#  'things': {u"dumbledore 's army": 1,
#             u'gryffindor house': 1,
#             u'quidditch cup': 1,
#             u'the chamber of secrets': 1,
#             u'the department of mysteries': 1,
#             u'the triwizard tournament': 1},
#  'times': {u'-PRON- early year': 1,
#            u'-PRON- fourth year': 1,
#            u'1991': 1,
#            u'the age of thirteen': 1,
#            u'year': 1},
#  'verbs': {u'attend': 1,
#            u'be': 1,
#            u'become': 3,
#            u'begin': 1,
#            u'conjure': 1,
#            u'end': 1,
#            u'fight': 1,
#            u'know': 1,
#            u'lead': 1,
#            u'learn': 2,
#            u'lose': 1,
#            u'protect': 1,
#            u'save': 1,
#            u'slay': 1,
#            u'solve': 1,
#            u'sort': 1,
#            u'teach': 1,
#            u'win': 2}}
# {'people': {u'albus dumbledore': 1,
#             u'colin creevey': 1,
#             u'fred weasley': 1,
#             u'harry': 4,
#             u'hermione': 1,
#             u'horcruxes': 1,
#             u'nymphadora tonks': 1,
#             u'remus lupin': 1,
#             u'ron': 1,
#             u'voldemort': 4},
#  'places': {u'voldemort': 1},
#  'things': {u'severus snape': 1,
#             u'the battle of': 1,
#             u'the second wizarding war': 1},
#  'times': {},
#  'verbs': {u'awake': 1,
#            u'be': 1,
#            u'choose': 2,
#            u'confront': 1,
#            u'curse': 1,
#            u'defeat': 1,
#            u'destroy': 2,
#            u'do': 1,
#            u'encounter': 1,
#            u'fall': 1,
#            u'give': 1,
#            u'hunt': 1,
#            u'know': 1,
#            u'learn': 1,
#            u'live': 2,
#            u'move': 1,
#            u'play': 1,
#            u'sacrifice': 1,
#            u'see': 1,
#            u'tell': 1}}
# {'people': {u'harry': 1},
#  'places': {},
#  'things': {u'master of death': 1},
#  'times': {u'deathly hallows': 1, u'seventeen': 1},
#  'verbs': {u'be': 2, u'know': 1, u'unite': 1}}
# {'people': {u'albus severus': 1,
#             u'edward remus lupin': 1,
#             u'ginny weasley': 1,
#             u'harry': 2,
#             u'head': 2,
#             u'james sirius': 1,
#             u'lily luna': 1,
#             u'luna lovegood': 1,
#             u'severus snape': 1},
#  'places': {u'auror': 1, u'hogwarts': 1},
#  'things': {u'albus dumbledore': 1,
#             u'defence against the dark arts': 1,
#             u'the auror office': 1,
#             u'the department of magical law enforcement': 1,
#             u'the ministry of magic': 1},
#  'times': {u'2007': 1, u'the age of 26': 1, u'the summer of 2020': 1},
#  'verbs': {u'be': 1,
#            u'become': 1,
#            u'deliver': 1,
#            u'go': 1,
#            u'have': 1,
#            u'help': 1,
#            u'lecture': 1,
#            u'marry': 1,
#            u'name': 4,
#            u'promote': 1,
#            u'revolutionise': 1}}
#
# Biography
#
#
# Family lineage
#
# {'people': {u'linfred': 1, u'potter': 2, u'potterer': 1},
#  'places': {},
#  'things': {u'linfred of stinchcombe': 1},
#  'times': {u'the year': 1},
#  'verbs': {u'be': 1,
#            u'call': 1,
#            u'corrupt': 1,
#            u'descend': 1,
#            u'give': 1,
#            u'lead': 1,
#            u'take': 1}}
# {'people': {u'gaunt': 1, u'hallows': 1, u'lord voldemort': 1, u'peverell': 1},
#  'places': {u'gaunts': 1},
#  'things': {u'cadmus peverell': 1,
#             u'ignotus peverell': 1,
#             u'iolanthe peverell': 1,
#             u'peverells': 1,
#             u'the cloak of invisibility': 1,
#             u'the resurrection stone': 1},
#  'times': {u'deathly hallows': 1},
#  'verbs': {u'be': 1,
#            u'create': 2,
#            u'descend': 2,
#            u'pass': 2,
#            u'relate': 1,
#            u'set': 1}}
# {'people': {u'abraham': 1, u'abraham potter': 1, u'harry': 2},
#  'places': {u'the united states of america': 1, u'us': 1},
#  'things': {u'macusa': 1, u'potters': 1, u'the magical congress': 1},
#  'times': {u'the 17th century': 1},
#  'verbs': {u'be': 1, u'develop': 1, u'hold': 1, u'migrate': 1, u'uncover': 1}}
# {'people': {u'euphemia': 1,
#             u'fleamont': 1,
#             u'hair potion': 1,
#             u'harry': 1,
#             u'henry potter': 1,
#             u'potter': 1,
#             u'ralston potter': 1,
#             u'wizengamot': 1},
#  'places': {},
#  'things': {u'fleamont': 1, u'sleekeazy': 1},
#  'times': {},
#  'verbs': {u'be': 1, u'hold': 1, u'inherit': 1, u'invent': 1, u'quadruple': 1}}
# {'people': {u'dudley dursley': 1,
#             u'harry': 2,
#             u'lily': 2,
#             u'lily evans': 1,
#             u'muggle': 1,
#             u'petunia': 1},
#  'places': {},
#  'things': {},
#  'times': {},
#  'verbs': {u'bear': 1, u'force': 1, u'have': 1, u'raise': 1}}
# {'people': {u'evans': 1,
#             u'harry': 2,
#             u'longbottoms': 1,
#             u'malfoys': 1,
#             u'muggles': 1,
#             u'weasleys': 1},
#  'places': {},
#  'things': {u'dursley': 1, u'potters': 1},
#  'times': {},
#  'verbs': {u'be': 2, u'consider': 1, u'know': 1, u'relate': 1}}
#
# Early life (1980-1981)
#
# {'people': {u'evans': 1,
#             u'harry james potter': 1,
#             u'james': 1,
#             u'lily potter': 1,
#             u'neville longbottom': 1},
#  'places': {u'phoenix': 1},
#  'things': {u'order of': 1},
#  'times': {u'1980': 1, u'31 july': 1, u'only hour': 1},
#  'verbs': {u'be': 1, u'bear': 1}}
# {'people': {u'harry': 3, u'james': 2, u'lily': 3, u'sirius': 1},
#  'places': {u'england': 1, u'godric': 1, u'the west country': 1},
#  'things': {u'the potter cottage': 1},
#  'times': {u'late 1979': 1},
#  'verbs': {u'be': 2,
#            u'bear': 1,
#            u'discover': 1,
#            u'go': 1,
#            u'hold': 1,
#            u'spend': 1}}
# {'people': {u'bathilda bagshot': 1,
#             u'harry': 3,
#             u'james': 1,
#             u'lily': 2,
#             u'sirius': 2},
#  'places': {u'voldemort': 1},
#  'things': {u'petunia': 1, u'potters': 1},
#  'times': {},
#  'verbs': {u'be': 4,
#            u'buy': 1,
#            u'happen': 1,
#            u'host': 1,
#            u'mention': 1,
#            u'own': 1,
#            u'sirius': 1,
#            u'smash': 1}}
# {'people': {u'albus dumbledore': 1,
#             u'harry': 1,
#             u'lord voldemort': 1,
#             u'peter pettigrew': 1,
#             u'pettigrew': 1,
#             u'potter': 1,
#             u'sirius black': 1,
#             u'voldemort': 1},
#  'places': {},
#  'things': {u'potters': 1, u'secret keeper': 1, u'the fidelius charm': 1},
#  'times': {u'a week later': 1, u'the end of july in 1980': 1},
#  'verbs': {u'be': 2,
#            u'bear': 1,
#            u'betray': 1,
#            u'change': 1,
#            u'keep': 1,
#            u'make': 1,
#            u'mark': 1,
#            u'plan': 1,
#            u'regard': 1,
#            u'suggest': 1,
#            u'think': 1,
#            u'use': 1}}
# {'people': {u'gaunt': 1,
#             u'godric': 1,
#             u'harry': 10,
#             u'hollow': 1,
#             u'hufflepuff': 1,
#             u'james': 2,
#             u'lily': 2,
#             u'lord voldemort': 2,
#             u'ravenclaw': 1,
#             u'slytherin': 1,
#             u'voldemort': 2},
#  'places': {u'parseltongue': 1, u'voldemort': 2},
#  'things': {u'the killing curse': 2, u'voldemort': 1},
#  'times': {u'1981': 1, u'the evening': 1, u'the year': 1},
#  'verbs': {u'advance': 1,
#            u'arrive': 1,
#            u'attempt': 1,
#            u'backfire': 1,
#            u'be': 1,
#            u'become': 1,
#            u'come': 1,
#            u'die': 1,
#            u'distract': 1,
#            u'fail': 1,
#            u'give': 3,
#            u'have': 1,
#            u'include': 2,
#            u'kill': 1,
#            u'latch': 1,
#            u'leave': 1,
#            u'lose': 1,
#            u'make': 2,
#            u'mark': 1,
#            u'murder': 3,
#            u'obliterate': 1,
#            u'open': 1,
#            u'prevent': 1,
#            u'protect': 2,
#            u'result': 1,
#            u'save': 1,
#            u'speak': 1,
#            u'survive': 1,
#            u'try': 2,
#            u'work': 1}}
# {'people': {u'hagrid': 2,
#             u'harry': 3,
#             u'james': 1,
#             u'lily': 1,
#             u'peter pettigrew': 1,
#             u'rubeus hagrid': 1,
#             u'sirius': 2,
#             u'sirius black': 1,
#             u'voldemort': 1},
#  'places': {u'dumbledore': 1, u'hagrid': 2},
#  'things': {u'albus dumbledore': 1, u'potters': 1, u'privet drive': 1},
#  'times': {},
#  'verbs': {u'be': 2,
#            u'choose': 1,
#            u'destroy': 1,
#            u'fake': 1,
#            u'find': 1,
#            u'fly': 1,
#            u'frame': 1,
#            u'give': 3,
#            u'intercept': 1,
#            u'kill': 1,
#            u'leave': 2,
#            u'plead': 1,
#            u'refuse': 1,
#            u'relent': 1,
#            u'rescue': 1,
#            u'say': 1,
#            u'take': 3}}
# {'people': {u'dumbledore': 1, u'dursleys': 1, u'harry': 3},
#  'places': {u'dumbledore': 1},
#  'things': {},
#  'times': {u'1 november 1981': 1, u'evening': 1, u'the next decade': 1},
#  'verbs': {u'be': 1,
#            u'deliver': 1,
#            u'know': 1,
#            u'leave': 1,
#            u'relay': 1,
#            u'spend': 1}}
#
# Life at Privet Drive (1981-1991)
#
# {'people': {u'dursleys': 2,
#             u'harry': 5,
#             u'james': 1,
#             u'killing curse': 1,
#             u'lily': 1},
#  'places': {u'voldemort': 1},
#  'things': {u'dursleys': 1, u'muggles': 1, u'petunia': 1, u'vernon': 1},
#  'times': {},
#  'verbs': {u'ask': 1,
#            u'avoid': 1,
#            u'be': 4,
#            u'claim': 2,
#            u'consider': 1,
#            u'could': 1,
#            u'despise': 1,
#            u'die': 1,
#            u'do': 2,
#            u'fail': 1,
#            u'forbid': 1,
#            u'have': 2,
#            u'know': 1,
#            u'laugh': 1,
#            u'lie': 1,
#            u'recall': 1,
#            u'receive': 1,
#            u'refuse': 1,
#            u'regard': 1,
#            u'strain': 1,
#            u'try': 1,
#            u'understand': 1,
#            u'want': 1}}
# {'people': {u'dedalus diggle': 1, u'harry': 5},
#  'places': {u'': 1},
#  'things': {u'dursleys': 1, u'petunia': 2},
#  'times': {u'the next morning': 1},
#  'verbs': {u'abuse': 1,
#            u'be': 2,
#            u'bow': 1,
#            u'could': 1,
#            u'deprive': 1,
#            u'discourage': 1,
#            u'do': 1,
#            u'grow': 1,
#            u'happen': 1,
#            u'interrogate': 1,
#            u'know': 2,
#            u'lay': 1,
#            u'leave': 3,
#            u'make': 1,
#            u'occur': 1,
#            u'punish': 1,
#            u'resent': 1,
#            u'shear': 1,
#            u'tell': 1,
#            u'treat': 1,
#            u'understand': 1,
#            u'use': 1}}
# {'people': {u'dudley': 3, u'dursleys': 2, u'harry': 5, u'piers polkiss': 1},
#  'places': {},
#  'things': {u'dudley': 1, u'vernon': 1},
#  'times': {u'every year': 1},
#  'verbs': {u'be': 4,
#            u'bully': 1,
#            u'do': 1,
#            u'get': 3,
#            u'make': 3,
#            u'pamper': 1,
#            u'pay': 2,
#            u'sleep': 2,
#            u'someplace': 1,
#            u'spoil': 1,
#            u'start': 1,
#            u'store': 1,
#            u'take': 1}}
# {'people': {u'aunt marge': 1,
#             u'dudley': 3,
#             u"dudley dursley 's": 1,
#             u'dursleys': 1,
#             u'harry': 5,
#             u'marge': 2,
#             u'petunia': 1,
#             u'potter': 1,
#             u'ripper': 1,
#             u'vernon': 1,
#             u'yvonne': 1},
#  'places': {},
#  'things': {u'dudley': 1,
#             u'dursleys': 1,
#             u'privet drive': 1,
#             u'ripper': 1,
#             u'vernon': 1},
#  'times': {u'christmas': 1},
#  'verbs': {u'be': 2,
#            u'beat': 1,
#            u'bring': 1,
#            u'call': 1,
#            u'cause': 1,
#            u'chase': 1,
#            u'consider': 1,
#            u'enrage': 1,
#            u'force': 1,
#            u'have': 1,
#            u'hide': 1,
#            u'know': 1,
#            u'laugh': 1,
#            u'make': 1,
#            u'refuse': 1,
#            u'show': 1,
#            u'step': 1,
#            u'stop': 1,
#            u'visit': 1,
#            u'whack': 1}}
# {'people': {u'harry': 4, u'lily': 1},
#  'places': {},
#  'things': {u'bond of blood': 1},
#  'times': {u'seventeen year old': 1},
#  'verbs': {u'be': 1,
#            u'break': 1,
#            u'call': 2,
#            u'continue': 1,
#            u'give': 1,
#            u'harm': 1,
#            u'live': 2,
#            u'return': 1,
#            u'turn': 1}}
# {'people': {u'albus dumbledore': 1,
#             u'arabella figg': 1,
#             u'dursleys': 1,
#             u'harry': 5,
#             u'squib': 1},
#  'places': {u'phoenix': 1},
#  'things': {u'dursleys': 1, u'the order of': 1},
#  'times': {u'-PRON- fifth year': 1},
#  'verbs': {u'be': 1,
#            u'discover': 1,
#            u'enjoy': 1,
#            u'force': 1,
#            u'give': 1,
#            u'go': 1,
#            u'have': 1,
#            u'infuriate': 1,
#            u'keep': 1,
#            u'know': 1,
#            u'let': 1,
#            u'look': 1,
#            u'maintain': 1,
#            u'reveal': 1,
#            u'work': 1}}
# {'people': {u'dursleys': 2, u'figg': 1, u'harry': 6, u'piers polkiss': 1},
#  'places': {u'parseltongue': 1},
#  'things': {u'dudley': 3, u'dursleys': 1},
#  'times': {u'23 june 1991': 1, u'summer': 1},
#  'verbs': {u'allow': 1,
#            u'be': 3,
#            u'break': 1,
#            u'communicate': 1,
#            u'disappear': 1,
#            u'enrage': 1,
#            u'go': 1,
#            u'have': 1,
#            u'leave': 1,
#            u'make': 1,
#            u'refuse': 1,
#            u'scar': 1,
#            u'sentence': 1,
#            u'slither': 2,
#            u'speak': 1,
#            u'take': 2,
#            u'thank': 1,
#            u'think': 1}}
#
# St. Grogory's Primary School
#
# {'people': {u'dudley': 3,
#             u'dursleys': 1,
#             u'grogory': 1,
#             u'harry': 6,
#             u"harry hunting '": 1},
#  'places': {},
#  'things': {u'aunt petunia': 1, u'dudley': 4, u'muggle': 1},
#  'times': {},
#  'verbs': {u'admit': 1,
#            u'apparat': 1,
#            u'attend': 1,
#            u'be': 4,
#            u'chase': 1,
#            u'do': 1,
#            u'enrage': 1,
#            u'escape': 1,
#            u'get': 1,
#            u'hat': 1,
#            u'have': 1,
#            u'involve': 1,
#            u'like': 2,
#            u'make': 1,
#            u'pick': 1,
#            u'play': 1,
#            u'punish': 1,
#            u'shove': 1,
#            u'shrink': 2,
#            u'think': 1,
#            u'throw': 1,
#            u'try': 1,
#            u'turn': 1,
#            u'want': 1}}
# {'people': {u'harry': 2, u'stonewall high': 1},
#  'places': {u'hogwarts': 1},
#  'things': {u'muggle': 1},
#  'times': {},
#  'verbs': {u'attend': 2, u'dread': 1, u'go': 1}}
#
# Discovery of being a wizard
#
# {'people': {u'dursleys': 5, u'harry': 5, u'uncle vernon': 1},
#  'places': {u'hogwarts school': 1},
#  'things': {u'dudley': 1, u'vernon': 1},
#  'times': {u'30 july 1991': 1,
#            u'the day': 1,
#            u'the same day': 1,
#            u'the week': 1},
#  'verbs': {u'address': 2,
#            u'appear': 1,
#            u'arrest': 1,
#            u'arrive': 1,
#            u'avoid': 1,
#            u'be': 2,
#            u'begin': 1,
#            u'call': 1,
#            u'carry': 1,
#            u'come': 1,
#            u'contact': 1,
#            u'destroy': 1,
#            u'discover': 1,
#            u'do': 1,
#            u'flee': 1,
#            u'fly': 1,
#            u'follow': 1,
#            u'go': 1,
#            u'have': 1,
#            u'keep': 2,
#            u'let': 1,
#            u'move': 1,
#            u'observe': 1,
#            u'panic': 1,
#            u'read': 1,
#            u'see': 2,
#            u'start': 1,
#            u'transfer': 1,
#            u'try': 2,
#            u'turn': 2}}
# {'people': {u'dumbledore': 1,
#             u'dursleys': 1,
#             u'harry': 4,
#             u'rubeus hagrid': 1},
#  'places': {},
#  'things': {u'hogwarts school of witchcraft': 1, u'vernon': 1},
#  'times': {u'midnight': 1},
#  'verbs': {u'appear': 1,
#            u'be': 2,
#            u'demand': 1,
#            u'die': 1,
#            u'explain': 1,
#            u'find': 1,
#            u'hat': 1,
#            u'infuriate': 1,
#            u'receive': 1,
#            u'ruin': 1,
#            u'send': 1,
#            u'take': 1}}
# {'people': {u'bathilda bagshot': 1,
#             u'dedalus diggle': 1,
#             u'diagon alley': 1,
#             u'doris crockford': 1,
#             u'harry': 5,
#             u'hedwig': 1,
#             u'quirinus quirrell': 1,
#             u'tom': 1},
#  'places': {u'hagrid': 3, u'hogwarts': 1},
#  'things': {u'gringotts wizarding bank': 1,
#             u'the dark arts': 1,
#             u'the inn -': 1,
#             u'the leaky cauldron': 1},
#  'times': {u'several year earlier': 1},
#  'verbs': {u'be': 3,
#            u'bow': 1,
#            u'find': 1,
#            u'give': 1,
#            u'learn': 2,
#            u'leave': 1,
#            u'meet': 1,
#            u'name': 2,
#            u'take': 2}}
# {'people': {u'dumbledore': 1,
#             u'fawkes': 2,
#             u'garrick ollivander': 1,
#             u'harry': 3,
#             u'lord voldemort': 1,
#             u'ollivander': 1,
#             u'riddle': 1,
#             u'tom riddle': 1},
#  'places': {},
#  'things': {},
#  'times': {u'the year': 1},
#  'verbs': {u'assume': 1,
#            u'attack': 1,
#            u'be': 1,
#            u'buy': 1,
#            u'choose': 2,
#            u'come': 2,
#            u'contain': 1,
#            u'craft': 1,
#            u'create': 1,
#            u'duel': 1,
#            u'end': 1,
#            u'have': 2,
#            u'make': 2,
#            u'prevent': 1,
#            u'share': 1,
#            u'supply': 1,
#            u'turn': 1,
#            u'use': 1}}
#
# Hogwarts years (1991-1997)
#
#
# First year
# {'people': {u'harry': 7, u'muggles': 1, u'platform nine': 1, u'ron': 2},
#  'places': {},
#  'things': {u'cross station': 1,
#             u'platform': 1,
#             u"the dursleys king 's": 1,
#             u'vernon': 1},
#  'times': {u'1 september , 1991': 1, u'eleven a.m.': 1, u'only ten minute': 1},
#  'verbs': {u'arrive': 1,
#            u'be': 2,
#            u'build': 1,
#            u'catch': 1,
#            u'complain': 1,
#            u'drop': 1,
#            u'follow': 1,
#            u'get': 1,
#            u'guide': 1,
#            u'have': 1,
#            u'head': 2,
#            u'help': 1,
#            u'interrupt': 1,
#            u'introduce': 1,
#            u'laugh': 1,
#            u'leave': 2,
#            u'near': 1,
#            u'notice': 1,
#            u'overhear': 1,
#            u'pack': 1,
#            u'panic': 1,
#            u'pass': 1,
#            u'push': 1,
#            u'run': 1,
#            u'start': 1,
#            u'watch': 1,
#            u'wheel': 1}}
# {'people': {u'fred weasley': 1,
#             u'george': 1,
#             u'ginny': 1,
#             u'harry': 5,
#             u'harry potter': 1,
#             u'percy': 1,
#             u'ron': 4},
#  'places': {u'prefect': 1},
#  'things': {u"a ronald weasley 's": 1, u'trolley': 1},
#  'times': {u'half - past': 1},
#  'verbs': {u'agree': 1,
#            u'ask': 3,
#            u'be': 5,
#            u'board': 1,
#            u'buy': 1,
#            u'change': 1,
#            u'come': 1,
#            u'depart': 1,
#            u'help': 1,
#            u'notice': 1,
#            u'recognise': 1,
#            u'report': 1,
#            u'share': 1,
#            u'sit': 2,
#            u'watch': 1}}
# {'people': {u'draco': 1,
#             u'draco malfoy': 1,
#             u'goyle': 1,
#             u'gregory goyle': 1,
#             u'harry': 3,
#             u'hermione': 1,
#             u'hermione granger': 1,
#             u'malfoy': 1,
#             u'neville longbottom': 1,
#             u'ron': 5,
#             u'scabbers': 1,
#             u'trevor': 2,
#             u'vincent crabbe': 1,
#             u'voldemort': 1},
#  'places': {},
#  'things': {u'chocolate frog cards': 1, u'scabbers': 1},
#  'times': {},
#  'verbs': {u'attempt': 2,
#            u'attmpt': 1,
#            u'be': 3,
#            u'believe': 1,
#            u'bewitch': 1,
#            u'bite': 1,
#            u'change': 1,
#            u'come': 2,
#            u'drive': 1,
#            u'explain': 1,
#            u'fail': 1,
#            u'find': 1,
#            u'help': 2,
#            u'inform': 1,
#            u'ingratiate': 1,
#            u'insult': 1,
#            u'interrupt': 2,
#            u'introduce': 1,
#            u'learn': 1,
#            u'refuse': 1,
#            u'say': 1,
#            u'search': 1,
#            u'shake': 1,
#            u'speculate': 1,
#            u'take': 1,
#            u'try': 1}}
# {'people': {u'hagrid': 1, u'neville': 1},
#  'places': {u'hagrid': 1},
#  'things': {},
#  'times': {u'the first year': 1},
#  'verbs': {u'arrive': 1,
#            u'climb': 1,
#            u'follow': 1,
#            u'gather': 1,
#            u'help': 1,
#            u'remind': 1,
#            u'sail': 1,
#            u'take': 2}}
#
# The Sorting ceremony and Start-of-Term Feast
#
# {'people': {u'draco malfoy': 1,
#             u'harry': 6,
#             u'hat': 1,
#             u'hermione granger': 1,
#             u'mcgonagall': 1,
#             u'minerva mcgonagall': 1,
#             u'ron': 2,
#             u'slytherin': 2,
#             u'voldemort': 1},
#  'places': {u'diagon alley': 1,
#             u'gryffindor': 1,
#             u'hagrid': 1,
#             u'ravenclaw': 1,
#             u'slytherin': 3,
#             u'voldemort': 1},
#  'things': {u'dark wizards': 1,
#             u'gryffindor , hufflepuff': 1,
#             u'house': 1,
#             u'the entrance hall': 1},
#  'times': {u'the first year': 1, u'the great hall': 1},
#  'verbs': {u'be': 3,
#            u'beg': 1,
#            u'describe': 1,
#            u'do': 2,
#            u'explain': 1,
#            u'feel': 1,
#            u'greet': 2,
#            u'lead': 2,
#            u'meet': 1,
#            u'note': 1,
#            u'place': 2,
#            u'put': 2,
#            u'remember': 1,
#            u'return': 1,
#            u'slip': 1,
#            u'tell': 3,
#            u'think': 1,
#            u'turn': 1,
#            u'wait': 1}}
# {'people': {u'dessert': 1, u'harry': 1, u'neville longbottom': 1},
#  'places': {},
#  'things': {u'squib': 1},
#  'times': {u"the first year ' family": 1},
#  'verbs': {u'allow': 1,
#            u'arrive': 1,
#            u'be': 1,
#            u'bounce': 1,
#            u'drop': 1,
#            u'eat': 1,
#            u'follow': 1,
#            u'overwhelm': 1,
#            u'tell': 1,
#            u'think': 1,
#            u'turn': 1,
#            u'want': 1}}
# {'people': {u'dumbledore': 1, u'harry': 3, u'quirrell': 2},
#  'places': {},
#  'things': {u'professor    quirrell': 1, u'the forbidden forest': 1},
#  'times': {},
#  'verbs': {u'add': 1,
#            u'avoid': 1,
#            u'be': 1,
#            u'feel': 1,
#            u'give': 1,
#            u'hurt': 1,
#            u'lead': 1,
#            u'look': 2,
#            u'melt': 1,
#            u'send': 1,
#            u'sing': 1,
#            u'stay': 1,
#            u'talk': 1,
#            u'welcome': 1}}
#
# First years lessons/classes
#
# {'people': {u'charlie weasley': 1,
#             u'diagon alley': 1,
#             u'fang': 1,
#             u'hagrid': 3,
#             u'harry': 6,
#             u'ron': 3,
#             u'snape': 1},
#  'places': {u'gringotts': 1, u'hagrid': 1},
#  'things': {u'hagrid \u2019s': 1,
#             u'potion': 1,
#             u'snape \u2019s': 1,
#             u'the daily prophet': 1},
#  'times': {u'vault 713': 1},
#  'verbs': {u'assert': 1,
#            u'begin': 1,
#            u'brew': 1,
#            u'detail': 1,
#            u'discover': 1,
#            u'go': 1,
#            u'hat': 1,
#            u'hate': 1,
#            u'have': 1,
#            u'lie': 1,
#            u'meet': 1,
#            u'mock': 1,
#            u'occur': 1,
#            u'overreact': 1,
#            u'pick': 1,
#            u'talk': 1,
#            u'teach': 1,
#            u'tell': 1,
#            u'visit': 1}}
# {'people': {u'harry': 1,
#             u'madam hooch': 1,
#             u"madam hooch 's": 1,
#             u'malfoy': 1,
#             u'neville': 1,
#             u'slytherins': 1},
#  'places': {u'neville': 1},
#  'things': {u'gryffindors': 1,
#             u'madam rolanda hooch': 1,
#             u'the hospital wing': 1},
#  'times': {},
#  'verbs': {u'be': 2,
#            u'brag': 1,
#            u'break': 1,
#            u'fall': 1,
#            u'find': 1,
#            u'fly': 2,
#            u'get': 1,
#            u'hover': 1,
#            u'kick': 1,
#            u'learn': 2,
#            u'leave': 1,
#            u'listen': 1,
#            u'look': 1,
#            u'panic': 1,
#            u'rise': 1,
#            u'start': 1,
#            u'stay': 1,
#            u'take': 2,
#            u'teach': 1,
#            u'tell': 1,
#            u'warn': 1}}
# {'people': {u'draco': 1, u'draco malfoy': 1, u'harry': 5},
#  'places': {u'neville': 1},
#  'things': {u'gryffindors': 1, u'remembrall': 2},
#  'times': {},
#  'verbs': {u'be': 2,
#            u'bend': 1,
#            u'catch': 2,
#            u'come': 1,
#            u'dare': 1,
#            u'discover': 1,
#            u'fly': 1,
#            u'give': 1,
#            u'grin': 1,
#            u'jeer': 1,
#            u'kick': 1,
#            u'leave': 1,
#            u'mount': 1,
#            u'need': 1,
#            u'nick': 1,
#            u'race': 1,
#            u'realise': 1,
#            u'shoot': 1,
#            u'stop': 1,
#            u'take': 1,
#            u'teach': 1,
#            u'tell': 1,
#            u'throw': 1,
#            u'topple': 1}}
# {'people': {u'charlie weasley': 1,
#             u'gryffindor quidditch': 1,
#             u'harry': 4,
#             u'mcgonagall': 2,
#             u'oliver wood': 1,
#             u'seeker': 1,
#             u'wood': 1},
#  'places': {},
#  'things': {u'the dark arts': 1},
#  'times': {u'a first year': 1},
#  'verbs': {u'arrive': 1,
#            u'be': 1,
#            u'compete': 1,
#            u'expect': 1,
#            u'explain': 1,
#            u'follow': 1,
#            u'hear': 1,
#            u'introduce': 2,
#            u'make': 1,
#            u'need': 1,
#            u'order': 1,
#            u'pull': 1,
#            u'recount': 1,
#            u'rival': 1,
#            u'see': 1,
#            u'tell': 1,
#            u'turn': 1}}
#
# The Midnight Duel
#
# {'people': {u'draco': 1,
#             u'gregory goyle': 1,
#             u'harry': 5,
#             u'hermione \u2019s': 1,
#             u'mcgonagall': 1,
#             u'ron': 1,
#             u'vincent crabbe': 1,
#             u'wood': 1},
#  'places': {},
#  'things': {},
#  'times': {u'night': 1},
#  'verbs': {u'accept': 1,
#            u'be': 1,
#            u'break': 1,
#            u'challenge': 1,
#            u'come': 1,
#            u'dissuade': 1,
#            u'enrage': 1,
#            u'escape': 1,
#            u'flank': 1,
#            u'get': 1,
#            u'happen': 1,
#            u'keep': 1,
#            u'leave': 1,
#            u'reward': 1,
#            u'taunt': 1,
#            u'tell': 1,
#            u'want': 1,
#            u'warn': 1}}
# {'people': {u'argus filch': 1,
#             u'draco': 1,
#             u'madam pomfrey': 1,
#             u'malfoy': 1,
#             u'mrs norris': 1,
#             u'neville': 1},
#  'places': {},
#  'things': {u'hogwarts': 1, u'peeve': 1},
#  'times': {},
#  'verbs': {u'arrive': 1,
#            u'attempt': 1,
#            u'be': 1,
#            u'burst': 1,
#            u'chicken': 1,
#            u'decide': 1,
#            u'do': 1,
#            u'enter': 1,
#            u'exit': 1,
#            u'expose': 1,
#            u'find': 2,
#            u'fix': 1,
#            u'forget': 1,
#            u'hear': 1,
#            u'leave': 1,
#            u'rattle': 1,
#            u'realise': 1,
#            u'speculate': 1,
#            u'threaten': 1,
#            u'trick': 1,
#            u'wait': 1}}
# {'people': {u'filch': 1,
#             u'harry': 1,
#             u'harry \u2019s': 1,
#             u'hermione': 1,
#             u'hermione \u2019s': 1,
#             u'ron': 1},
#  'places': {},
#  'things': {u'peeve': 1, u'the unlocking charm': 1},
#  'times': {u'the night': 1},
#  'verbs': {u'attract': 1,
#            u'begin': 1,
#            u'bellow': 1,
#            u'choose': 1,
#            u'come': 1,
#            u'could': 1,
#            u'explore': 1,
#            u'find': 1,
#            u'get': 1,
#            u'grow': 1,
#            u'hurry': 1,
#            u'lock': 1,
#            u'manage': 1,
#            u'open': 1,
#            u'pique': 1,
#            u'point': 1,
#            u'run': 3,
#            u'shake': 1,
#            u'stand': 1,
#            u'stop': 1,
#            u'take': 1,
#            u'think': 1,
#            u'turn': 1,
#            u'use': 1}}
#
# The Nimbus 2000
#
# {'people': {u'flitwick': 2,
#             u'harry': 5,
#             u'harry \u2019s': 2,
#             u'malfoy': 1,
#             u'mcgonagall': 1,
#             u'ron': 2,
#             u'wood': 1},
#  'places': {u'hagrid \u2019s': 1},
#  'things': {u'fluffy': 1, u'nimbus': 1, u'quidditch': 1},
#  'times': {u'first - year': 1, u'night': 1, u'that morning': 1},
#  'verbs': {u'allow': 1,
#            u'arrive': 1,
#            u'be': 3,
#            u'discover': 1,
#            u'discuss': 1,
#            u'express': 1,
#            u'guard': 1,
#            u'intrigue': 1,
#            u'meet': 1,
#            u'open': 1,
#            u'receive': 1,
#            u'report': 1,
#            u'seize': 1,
#            u'shape': 1,
#            u'stop': 1,
#            u'take': 1,
#            u'tell': 2,
#            u'try': 1,
#            u'walk': 1,
#            u'warn': 1}}
#
# Hallowe'en
#
# {'people': {u'flitwick': 1, u'harry': 4, u'hermione': 2, u'ron': 4},
#  'places': {u'quirrell': 1},
#  'things': {u"hallowe'en": 2, u'hermione': 1, u'partway': 1},
#  'times': {},
#  'verbs': {u'announce': 1,
#            u'arrive': 1,
#            u'be': 2,
#            u'begin': 1,
#            u'cause': 1,
#            u'convince': 1,
#            u'faint': 1,
#            u'feel': 1,
#            u'forget': 1,
#            u'go': 1,
#            u'hear': 1,
#            u'help': 1,
#            u'knock': 1,
#            u'know': 1,
#            u'lead': 1,
#            u'levitate': 1,
#            u'lock': 2,
#            u'make': 2,
#            u'offend': 1,
#            u'realise': 2,
#            u'rescue': 1,
#            u'run': 2,
#            u'save': 1,
#            u'smash': 1,
#            u'sneak': 1,
#            u'stand': 1,
#            u'stick': 1,
#            u'succeed': 1,
#            u'teach': 1,
#            u'warn': 1}}
# {'people': {u'harry': 3,
#             u'hermione': 2,
#             u'mcgonagall': 2,
#             u'ron': 2,
#             u'ron \u2019s': 1},
#  'places': {},
#  'things': {u'gryffindor': 1},
#  'times': {},
#  'verbs': {u'arrive': 1,
#            u'attract': 1,
#            u'be': 3,
#            u'begin': 1,
#            u'bond': 1,
#            u'claim': 1,
#            u'cover': 1,
#            u'fail': 1,
#            u'find': 1,
#            u'go': 2,
#            u'handle': 1,
#            u'lie': 1,
#            u'look': 2,
#            u'put': 1,
#            u'rescue': 1,
#            u'scold': 1,
#            u'tell': 1,
#            u'think': 1,
#            u'yell': 1}}
#
# Quidditch
#
# {'people': {u'harry': 4, u'hermione': 3, u'ron': 1, u'slytherin': 1},
#  'places': {},
#  'things': {u'quidditch through the age': 1},
#  'times': {u'the day': 1, u'the quidditch season': 1},
#  'verbs': {u'be': 4,
#            u'become': 1,
#            u'begin': 1,
#            u'borrow': 1,
#            u'calm': 1,
#            u'check': 1,
#            u'conjure': 1,
#            u'entitle': 1,
#            u'huddle': 1,
#            u'increase': 1,
#            u'keep': 1,
#            u'show': 1}}
# {'people': {u'filch': 1, u'harry': 5, u'harry \u2019s': 1, u'snape': 5},
#  'places': {u'filch': 1},
#  'things': {u'fluffy': 1, u'the common room': 1, u'the potions master': 1},
#  'times': {u"the next day 's": 1},
#  'verbs': {u'approach': 1,
#            u'ask': 1,
#            u'bandage': 1,
#            u'be': 5,
#            u'bully': 1,
#            u'complain': 1,
#            u'confiscate': 1,
#            u'confront': 1,
#            u'decide': 2,
#            u'guard': 1,
#            u'help': 1,
#            u'injure': 1,
#            u'limp': 1,
#            u'look': 1,
#            u'notice': 2,
#            u'open': 1,
#            u'overhear': 1,
#            u'punish': 1,
#            u'realise': 1,
#            u'return': 1,
#            u'see': 2,
#            u'strengthen': 1,
#            u'take': 1,
#            u'tell': 1}}
# {'people': {u'gryffindor seeker': 1,
#             u'hagrid': 1,
#             u'harry': 4,
#             u'harry \u2019s': 2,
#             u'hermione': 1,
#             u'ron': 1,
#             u'seeker': 1},
#  'places': {u'quidditch': 1, u'the snape \u2019s': 1},
#  'things': {u'magic': 1, u'snitch': 1, u'the slytherin seeker': 1},
#  'times': {u'a second year': 1},
#  'verbs': {u'arrive': 1,
#            u'be': 7,
#            u'become': 1,
#            u'begin': 3,
#            u'blatch': 1,
#            u'buck': 1,
#            u'catch': 2,
#            u'do': 1,
#            u'dwell': 1,
#            u'foil': 1,
#            u'get': 1,
#            u'hang': 1,
#            u'have': 1,
#            u'help': 1,
#            u'make': 1,
#            u'manage': 1,
#            u'note': 1,
#            u'pass': 1,
#            u'penalise': 1,
#            u'rest': 1,
#            u'see': 1,
#            u'stop': 1,
#            u'succeed': 1,
#            u'take': 1,
#            u'try': 1,
#            u'unseat': 1,
#            u'watch': 1,
#            u'wonder': 1}}
# {'people': {u'harry': 5,
#             u'harry \u2019s': 1,
#             u'hermione': 2,
#             u'quirrell': 1,
#             u'snape': 2,
#             u'snitch': 1},
#  'places': {u'gryffindor': 1},
#  'things': {u'bluebell flames': 1, u'hermione light snape': 1, u'weasley': 1},
#  'times': {},
#  'verbs': {u'be': 2,
#            u'break': 1,
#            u'catch': 1,
#            u'choose': 1,
#            u'clasp': 1,
#            u'control': 1,
#            u'do': 1,
#            u'end': 2,
#            u'focus': 1,
#            u'knock': 1,
#            u'land': 1,
#            u'light': 1,
#            u'mutter': 2,
#            u'notice': 1,
#            u'rescue': 1,
#            u'run': 1,
#            u'scan': 1,
#            u'scoop': 1,
#            u'star': 1,
#            u'take': 1,
#            u'tell': 1,
#            u'think': 1,
#            u'turn': 1,
#            u'watch': 1,
#            u'win': 1}}
# {'people': {u'albus dumbledore': 1,
#             u'harry': 3,
#             u'hermione': 1,
#             u'nicolas flamel': 1,
#             u'ron': 1,
#             u'snape': 2},
#  'places': {u'hagrid': 3},
#  'things': {u'hagrid': 2, u'snape': 1},
#  'times': {},
#  'verbs': {u'ask': 1,
#            u'be': 1,
#            u'believe': 1,
#            u'belong': 1,
#            u'bite': 1,
#            u'concern': 1,
#            u'curse': 1,
#            u'guard': 1,
#            u'happen': 1,
#            u'kill': 1,
#            u'know': 1,
#            u'name': 1,
#            u'reveal': 1,
#            u'take': 1,
#            u'tell': 2,
#            u'try': 1}}
#
# Christmas season
#
# {'people': {u'dursleys': 1,
#             u'harry': 4,
#             u'malfoy': 1,
#             u'nicolas flamel': 1,
#             u'ron': 1},
#  'places': {u'hogwarts': 2},
#  'things': {},
#  'times': {u'christmas': 1, u'flamel in': 1},
#  'verbs': {u'be': 6,
#            u'buck': 1,
#            u'find': 3,
#            u'force': 1,
#            u'give': 1,
#            u'have': 1,
#            u'hold': 1,
#            u'impress': 1,
#            u'look': 2,
#            u'manage': 1,
#            u'replace': 1,
#            u'revert': 1,
#            u'search': 1,
#            u'spend': 1,
#            u'stay': 2,
#            u'tease': 1}}
# {'people': {u'harry': 4, u'ron': 1},
#  'places': {u'filch': 1},
#  'things': {u'cloak': 1,
#             u'filch \u2019s': 1,
#             u'invisibility cloak': 1,
#             u'the restricted section': 1},
#  'times': {u'christmas day': 1, u'that night': 1},
#  'verbs': {u'awake': 1,
#            u'be': 1,
#            u'belong': 1,
#            u'bring': 1,
#            u'contain': 1,
#            u'decide': 1,
#            u'duck': 1,
#            u'fall': 1,
#            u'find': 1,
#            u'go': 1,
#            u'have': 1,
#            u'head': 1,
#            u'issue': 1,
#            u'knock': 1,
#            u'know': 1,
#            u'let': 1,
#            u'open': 1,
#            u'pull': 1,
#            u'realise': 1,
#            u'run': 2,
#            u'sneak': 1,
#            u'start': 1,
#            u'stuff': 1,
#            u'tell': 1,
#            u'try': 1,
#            u'use': 1}}
# {'people': {u'filch': 3,
#             u'filch \u2019s': 1,
#             u'harry': 4,
#             u'snape': 3,
#             u'\u2019s': 1},
#  'places': {},
#  'things': {},
#  'times': {},
#  'verbs': {u'abandon': 1,
#            u'approach': 1,
#            u'be': 4,
#            u'escape': 1,
#            u'find': 1,
#            u'have': 1,
#            u'hear': 1,
#            u'horrify': 1,
#            u'make': 1,
#            u'notice': 1,
#            u'panic': 1,
#            u'pass': 1,
#            u'realise': 2,
#            u'relax': 1,
#            u'round': 1,
#            u'slip': 1,
#            u'sneak': 1,
#            u'stop': 1,
#            u'take': 1,
#            u'talk': 1,
#            u'think': 1}}
# {'people': {u'harry': 6, u'harry \u2019s': 1},
#  'places': {},
#  'things': {},
#  'times': {},
#  'verbs': {u'bear': 1,
#            u'cry': 1,
#            u'do': 1,
#            u'eris': 1,
#            u'focus': 1,
#            u'have': 4,
#            u'look': 5,
#            u'miss': 1,
#            u'notice': 1,
#            u'realise': 1,
#            u'see': 4,
#            u'shock': 1,
#            u'stand': 1,
#            u'step': 1,
#            u'turn': 2,
#            u'understand': 1}}
# {'people': {u'filch \u2019s': 1,
#             u'harry': 3,
#             u'harry \u2019s': 1,
#             u'head boy': 1,
#             u'mrs norris': 1,
#             u'quidditch captain': 1,
#             u'ron': 3},
#  'places': {},
#  'things': {u'the house cup': 1},
#  'times': {u'the next day': 1},
#  'verbs': {u'allow': 1,
#            u'argue': 1,
#            u'attract': 1,
#            u'be': 2,
#            u'begin': 1,
#            u'bring': 1,
#            u'catch': 1,
#            u'dissuade': 1,
#            u'enter': 1,
#            u'hold': 1,
#            u'indicate': 1,
#            u'look': 1,
#            u'prowl': 1,
#            u'return': 1,
#            u'see': 2,
#            u'stand': 1,
#            u'warn': 1,
#            u'wear': 1}}
# {'people': {u'dumbledore': 2, u'harry': 3, u'ron': 1},
#  'places': {},
#  'things': {u'mirror of erised': 1},
#  'times': {u'evening': 1, u'night': 1},
#  'verbs': {u'be': 2,
#            u'display': 1,
#            u'explain': 1,
#            u'fail': 1,
#            u'go': 1,
#            u'know': 2,
#            u'look': 1,
#            u'lose': 1,
#            u'notice': 1,
#            u'overshadow': 1,
#            u'remove': 1,
#            u'see': 2,
#            u'stand': 3,
#            u'star': 1,
#            u'stay': 1,
#            u'wait': 1}}
# {'people': {u'dumbledore': 2, u'harry': 6, u'snape': 1, u'wood': 1},
#  'places': {u'dumbledore': 1, u'quidditch': 1},
#  'things': {u'hufflepuff': 1},
#  'times': {},
#  'verbs': {u'ask': 1,
#            u'be': 3,
#            u'drive': 1,
#            u'find': 1,
#            u'forget': 1,
#            u'go': 1,
#            u'know': 1,
#            u'leave': 1,
#            u'look': 1,
#            u'move': 1,
#            u'referee': 1,
#            u'see': 4,
#            u'send': 1,
#            u'tell': 3,
#            u'warn': 2}}
# {'people': {u'chocolate frog': 1,
#             u'dumbledore': 1,
#             u'harry': 4,
#             u'malfoy': 2,
#             u'neville': 2,
#             u'nicolas flamel': 1},
#  'places': {u'neville': 2},
#  'things': {u'common room': 1, u'leg - locker': 1},
#  'times': {},
#  'verbs': {u'be': 2,
#            u'force': 1,
#            u'get': 1,
#            u'give': 1,
#            u'hand': 1,
#            u'hop': 1,
#            u'look': 1,
#            u'note': 1,
#            u'pick': 1,
#            u'read': 1,
#            u'remember': 1,
#            u'tell': 1,
#            u'thank': 1,
#            u'turn': 1,
#            u'use': 1}}
# {'people': {u'gryffindor': 1,
#             u'harry': 5,
#             u'hermione': 1,
#             u'hufflepuff': 1,
#             u'ron': 1,
#             u'seeker': 1,
#             u'snape': 2,
#             u'wood': 1},
#  'places': {u'gryffindor': 1,
#             u'slytherin': 1,
#             u'the gryffindor vs.': 1,
#             u'the quidditch cup': 1},
#  'things': {u'hufflepuff quidditch': 1,
#             u'inter - house quidditch': 1,
#             u'leg - locker curse': 1,
#             u'snape': 1},
#  'times': {u'five minute': 1, u'seven year': 1},
#  'verbs': {u'be': 3,
#            u'begin': 1,
#            u'catch': 2,
#            u'could': 1,
#            u'draw': 1,
#            u'fail': 1,
#            u'favour': 1,
#            u'harm': 1,
#            u'mount': 1,
#            u'need': 1,
#            u'overtake': 1,
#            u'perform': 1,
#            u'practise': 1,
#            u'put': 1,
#            u'remind': 1,
#            u'show': 1,
#            u'start': 1,
#            u'take': 1,
#            u'use': 1,
#            u'want': 1}}
#
# Detention
#
# {'people': {u'draco malfoy': 1,
#             u'harry': 2,
#             u'hermione': 2,
#             u'malfoy': 1,
#             u'mcgonagall': 1,
#             u'ron': 1,
#             u'rubeus hagrid': 1},
#  'places': {u'flitwick': 1, u'hagrid': 3, u'mcgonagall': 1, u'quirrell': 1},
#  'things': {u'fluffy': 1, u'professors sprout': 1, u'snape': 1, u'stone': 1},
#  'times': {u'the day': 1},
#  'verbs': {u'answer': 1,
#            u'arrive': 1,
#            u'ask': 1,
#            u'be': 2,
#            u'decide': 1,
#            u'discover': 1,
#            u'do': 1,
#            u'get': 2,
#            u'grow': 1,
#            u'guard': 1,
#            u'have': 1,
#            u'light': 1,
#            u'manage': 1,
#            u'manipulate': 1,
#            u'meet': 1,
#            u'notice': 1,
#            u'open': 1,
#            u'possess': 1,
#            u'realise': 1,
#            u'refuse': 1,
#            u'run': 1,
#            u'talk': 1,
#            u'tell': 2,
#            u'try': 1,
#            u'use': 2,
#            u'work': 1}}
# {'people': {u'charlie': 1,
#             u'charlie weasley': 1,
#             u'harry': 5,
#             u'hermione': 3,
#             u'malfoy': 1,
#             u'mcgonagall': 1,
#             u'norbert': 4,
#             u'ron': 4},
#  'places': {u'hagrid': 2},
#  'things': {u'argus filch': 1,
#             u'cloak': 1,
#             u'invisibility': 1,
#             u'romanian': 1,
#             u'the astronomy tower': 1},
#  'times': {u'night': 2},
#  'verbs': {u'arrange': 1,
#            u'be': 2,
#            u'cause': 1,
#            u'confront': 1,
#            u'convince': 1,
#            u'force': 1,
#            u'haul': 1,
#            u'head': 1,
#            u'help': 1,
#            u'involve': 1,
#            u'leave': 1,
#            u'manage': 1,
#            u'pass': 1,
#            u'prepare': 1,
#            u'preserve': 1,
#            u'protest': 1,
#            u'save': 1,
#            u'see': 1,
#            u'send': 1,
#            u'smuggle': 1,
#            u'swell': 1,
#            u'take': 1,
#            u'witness': 1}}
# {'people': {u'dumbledore': 1,
#             u'gryffindor': 1,
#             u'harry': 4,
#             u'hermione': 2,
#             u'malfoy': 2,
#             u'mcgonagall': 2,
#             u'neville': 2,
#             u'quirrell': 1,
#             u'slytherin': 1,
#             u'snape': 1},
#  'places': {u'quidditch': 1, u'stone': 1},
#  'things': {u'quirrell': 1, u'the house cup': 1},
#  'times': {u'week': 1},
#  'verbs': {u'attempt': 1,
#            u'be': 3,
#            u'believe': 1,
#            u'defeat': 1,
#            u'dismiss': 1,
#            u'find': 1,
#            u'give': 1,
#            u'go': 2,
#            u'have': 1,
#            u'hear': 1,
#            u'lose': 1,
#            u'meddle': 1,
#            u'plummet': 1,
#            u'rid': 1,
#            u'serve': 1,
#            u'suggest': 1,
#            u'take': 2,
#            u'talk': 2,
#            u'test': 1,
#            u'threaten': 2,
#            u'want': 1,
#            u'warn': 1,
#            u'win': 2}}
# {'people': {u'fang': 1,
#             u'hagrid': 2,
#             u'harry': 4,
#             u'hermione': 2,
#             u'malfoy': 3,
#             u'mcgonagall': 1,
#             u'neville': 2},
#  'places': {u'hagrid': 2, u'the forbidden forest': 1},
#  'things': {u'argus filch': 1,
#             u'malfoy': 1,
#             u'neville': 1,
#             u'the forbidden forest': 1},
#  'times': {u'night': 1},
#  'verbs': {u'be': 1,
#            u'begin': 1,
#            u'decide': 1,
#            u'go': 1,
#            u'inform': 1,
#            u'lead': 1,
#            u'receive': 1,
#            u'scar': 1,
#            u'scare': 1,
#            u'send': 2,
#            u'show': 1,
#            u'split': 1,
#            u'take': 2,
#            u'wait': 1}}
# {'people': {u'fang': 1,
#             u'firenze': 1,
#             u'harry': 6,
#             u'lord voldemort': 1,
#             u'malfoy': 1},
#  'places': {},
#  'things': {u'': 1, u'firenze': 1},
#  'times': {},
#  'verbs': {u'advance': 1,
#            u'allow': 1,
#            u'be': 2,
#            u'begin': 1,
#            u'blind': 1,
#            u'bolt': 1,
#            u'come': 1,
#            u'continue': 1,
#            u'drink': 1,
#            u'emerge': 1,
#            u'find': 1,
#            u'follow': 1,
#            u'grow': 1,
#            u'kill': 1,
#            u'lay': 1,
#            u'leave': 1,
#            u'notice': 1,
#            u'realise': 1,
#            u'ride': 1,
#            u'save': 1,
#            u'scream': 1,
#            u'seem': 1,
#            u'stumble': 1,
#            u'tell': 1,
#            u'thrash': 1,
#            u'watch': 1}}
#
# The Philosopher's Stone
#
# {'people': {u'dumbledore': 2,
#             u'hagrid': 2,
#             u'harry': 2,
#             u'hermione': 1,
#             u'hogwarts': 1,
#             u'mcgonagall': 1,
#             u'norbert': 1,
#             u'ron': 2,
#             u'snape': 1},
#  'places': {u'hagrid': 3, u'hogs': 1, u'london': 1},
#  'things': {u'fluffy': 2,
#             u'hermione': 1,
#             u'stone': 1,
#             u'the entrance hall': 1},
#  'times': {u'night': 1, u'the day': 1},
#  'verbs': {u'ask': 1,
#            u'be': 1,
#            u'buy': 1,
#            u'decide': 2,
#            u'explain': 1,
#            u'fall': 1,
#            u'find': 2,
#            u'finish': 1,
#            u'focus': 1,
#            u'get': 1,
#            u'give': 2,
#            u'go': 1,
#            u'happen': 1,
#            u'have': 1,
#            u'insist': 1,
#            u'keep': 1,
#            u'let': 1,
#            u'look': 1,
#            u'lower': 1,
#            u'meet': 1,
#            u'need': 1,
#            u'occur': 1,
#            u'play': 1,
#            u'realise': 1,
#            u'remember': 2,
#            u'run': 1,
#            u'say': 1,
#            u'see': 1,
#            u'slip': 1,
#            u'steal': 1,
#            u'stop': 1,
#            u'talk': 2,
#            u'tell': 3,
#            u'think': 1,
#            u'walk': 1,
#            u'want': 1}}
# {'people': {u"devil 's": 1,
#             u'gryffindor': 1,
#             u'harry': 1,
#             u'hermione': 1,
#             u'neville': 2,
# ...
#             u'malfoy': 1,
#             u'the elder wand': 1},
#  'places': {u'dumbledore': 1, u'snape': 1, u'voldemort': 1},
#  'things': {u'the elder wand': 1},
#  'times': {u'malfoy manor week earlier': 1},
#  'verbs': {u'become': 1, u'disarm': 1, u'steal': 1, u'take': 1}}
# {'people': {u'elder': 1, u'harry': 4, u'voldemort': 1},
#  'places': {u'voldemort': 3},
#  'things': {u'the disarming charm': 1, u'the killing curse': 2},
#  'times': {},
#  'verbs': {u'ask': 1,
#            u'attack': 1,
#            u'cast': 1,
#            u'counter': 1,
#            u'destroy': 1,
#            u'face': 1,
#            u'feel': 1,
#            u'make': 1,
#            u'rebound': 1,
#            u'refuse': 1,
#            u'reject': 1,
#            u'tell': 1,
#            u'try': 1}}
# {'people': {u'harry': 3,
#             u'hermione': 2,
#             u'kingsley shacklebolt': 1,
#             u'luna': 2,
#             u'ron': 2},
#  'places': {u'azkaban': 1, u'neville': 1},
#  'things': {u'ginny': 1, u'invisibility cloak': 1, u'magic': 1},
#  'times': {},
#  'verbs': {u'be': 1,
#            u'begin': 1,
#            u'capture': 1,
#            u'come': 1,
#            u'create': 1,
#            u'find': 1,
#            u'flee': 1,
#            u'grow': 1,
#            u'guide': 1,
#            u'hear': 1,
#            u'name': 1,
#            u'reach': 1,
#            u'release': 1,
#            u'slip': 1,
#            u'speak': 1,
#            u'surround': 1,
#            u'want': 1,
#            u'witness': 1}}
# {'people': {u"albus dumbledore 's": 1,
#             u'deathly hallows': 1,
#             u'dumbledore': 1,
#             u'harry': 1},
#  'places': {},
#  'things': {u'the cloak of invisibility ,': 1,
#             u'the elder wand': 1,
#             u'the forbidden forest': 1,
#             u'the resurrection stone': 1},
#  'times': {},
#  'verbs': {u'decide': 1,
#            u'explain': 1,
#            u'fix': 1,
#            u'keep': 1,
#            u'leave': 1,
#            u'lie': 1,
#            u'prevent': 1,
#            u'return': 1,
#            u'reunite': 1,
#            u'use': 1,
#            u'visit': 1}}
# {'people': {u'harry': 1},
#  'places': {u'harry': 1, u'voldemort': 1},
#  'things': {u'parseltongue': 1},
#  'times': {},
#  'verbs': {u'destroy': 1, u'lose': 1, u'reside': 1, u'speak': 1}}
#
# Later life (1998-2020)
#
# {'people': {u'harry': 1},
#  'places': {u'hogwarts': 1},
#  'things': {u'chocolate frog cards': 1,
#             u'headmaster': 1,
#             u"severus snape 's": 1,
#             u'the dark arts': 1},
#  'times': {},
#  'verbs': {u'ensure': 1, u'feature': 1, u'give': 1, u'hang': 1, u'make': 1}}
# {'people': {u'draco malfoy': 1,
#             u'dudley dursley': 1,
#             u'harry': 2,
#             u'severus snape': 1},
#  'places': {},
#  'things': {},
#  'times': {u'christmas': 1},
#  'verbs': {u'be': 5,
#            u'do': 1,
#            u'dread': 1,
#            u'make': 1,
#            u'mean': 1,
#            u'visit': 1}}
# {'people': {u'bill': 1,
#             u'harry': 3,
#             u'sirius black': 1,
#             u'teddy': 4,
#             u'teddy lupin': 1},
#  'places': {u'fleur weasley': 1},
#  'things': {u'victoire weasley': 1},
#  'times': {},
#  'verbs': {u'aid': 1,
#            u'be': 2,
#            u'become': 2,
#            u'come': 1,
#            u'comment': 1,
#            u'follow': 1,
#            u'fulfil': 1,
#            u'get': 1,
#            u'live': 1,
#            u'mention': 1,
#            u'move': 1,
#            u'play': 1,
#            u'see': 1,
#            u'snog': 1,
#            u'thrill': 1,
#            u'want': 1}}
#
# Career as an Auror
#
# {'people': {u'auror': 1,
#             u'harry': 3,
#             u'head': 1,
#             u'hermione granger': 1,
#             u'ron weasley': 1},
#  'places': {},
#  'things': {u'kingsley': 1,
#             u'magic kingsley shacklebolt': 1,
#             u'n.e.w.t.s': 1,
#             u'the auror office': 1,
#             u'the department of magical law enforcement': 1,
#             u'the ministry of magic': 1},
#  'times': {u'2007': 1, u'the age of 26 or 27': 1, u'the end of': 1},
#  'verbs': {u'become': 4,
#            u'consider': 1,
#            u'fight': 1,
#            u'get': 1,
#            u'help': 1,
#            u'permit': 1,
#            u'rank': 1,
#            u'recruit': 1,
#            u'revolutionise': 1}}
# {'people': {u'albus': 2,
#             u'albus severus': 1,
#             u'dumbledore': 1,
#             u'ginny': 1,
#             u'ginny potter': 1,
#             u'harry': 6,
#             u'james': 2,
#             u'james sirius': 1,
#             u'lily luna': 1,
#             u'teddy lupin': 1,
#             u'viktor krum': 2},
#  'places': {u'bulgaria': 1, u'patagonia': 1},
#  'things': {u'albus': 1,
#             u'army': 1,
#             u'quidditch': 1,
#             u'the 427th quidditch world cup': 1,
#             u'the auror office': 1,
#             u'the daily prophet': 1},
#  'times': {u'2005': 1,
#            u'2014': 1,
#            u'2017': 1,
#            u'a few year': 1,
#            u'cup': 1,
#            u'early july of 2014': 1},
#  'verbs': {u'attend': 1,
#            u'be': 2,
#            u'compete': 1,
#            u'embrace': 1,
#            u'grant': 1,
#            u'have': 1,
#            u'include': 1,
#            u'introduce': 1,
#            u'join': 1,
#            u'look': 1,
#            u'marry': 1,
#            u'meet': 1,
#            u'retire': 1,
#            u'save': 1,
#            u'sport': 1,
#            u'support': 1,
#            u'win': 1}}
# {'people': {u'blotts': 1,
#             u'ginny': 1,
#             u'harry': 1,
#             u'rita': 1,
#             u'rita skeeter': 1},
#  'places': {u'd.a.': 1},
#  'things': {u"dumbledore 's army": 2, u'the dark side of the demob': 1},
#  'times': {u'31 july , 2014': 1},
#  'verbs': {u'accord': 1,
#            u'feature': 1,
#            u'focus': 1,
#            u'launch': 1,
#            u'regard': 1,
#            u'seem': 1,
#            u'title': 1}}
# {'people': {u'albus': 3,
#             u'ginny': 1,
#             u'harry': 4,
#             u'hermione': 1,
#             u'james': 1,
#             u'ron': 1,
#             u'rose': 1},
#  'places': {u'hogwarts': 1, u'slytherin': 1},
#  'things': {u'hogwarts headmasters': 1,
#             u"king 's cross station": 1,
#             u'slytherin house': 1,
#             u'sort': 1},
#  'times': {u'hugo': 1, u'september , 2017': 1},
#  'verbs': {u'assure': 1,
#            u'be': 3,
#            u'express': 1,
#            u'happen': 1,
#            u'know': 1,
#            u'meet': 1,
#            u'name': 1,
#            u'see': 1,
#            u'share': 1,
#            u'sort': 3,
#            u'take': 2,
#            u'tell': 2}}
#
# Head of Department of Magical Law Enforcement
#
# {'people': {},
#  'places': {u'albus': 1, u'hogwarts': 1},
#  'things': {u'albus': 1, u"king 's cross": 1},
#  'times': {u'a year': 1, u'the next couple of year': 1},
#  'verbs': {u'be': 1, u'find': 1, u'pick': 1, u'return': 1, u'stay': 1}}
# {'people': {u'albus': 2, u'cross': 1, u'harry': 2, u'scorpius malfoy': 1},
#  'places': {},
#  'things': {u'albus': 1},
#  'times': {u'september 2018': 1},
#  'verbs': {u'be': 2,
#            u'demand': 1,
#            u'hurt': 1,
#            u'refuse': 1,
#            u'sever': 1,
#            u'take': 1,
#            u'tell': 1,
#            u'think': 1,
#            u'want': 1}}
# {'people': {u'albus': 2, u'cross': 1, u'harry': 2, u'hogsmeade': 1},
#  'places': {},
#  'things': {u'albus': 1},
#  'times': {u'september 2019': 1},
#  'verbs': {u'destroy': 1,
#            u'give': 1,
#            u'leave': 1,
#            u'need': 1,
#            u'slip': 1,
#            u'take': 1,
#            u'visit': 1}}
# {'people': {u'harry': 2,
#             u'head': 1,
#             u'hermione': 1,
#             u'theodore nott': 1,
#             u'voldemort': 1},
#  'places': {},
#  'things': {u'ministry of magic': 1,
#             u'the department of    magical law enforcement': 1,
#             u'time - turner': 1},
#  'times': {u'late summer of 2020': 1},
#  'verbs': {u'confiscate': 1,
#            u'help': 1,
#            u'make': 1,
#            u'return': 1,
#            u'speak': 1}}
# {'people': {u'albus': 1,
#             u'amos': 2,
#             u'amos diggory': 1,
#             u'cedric': 1,
#             u'delphi diggory': 1,
#             u'harry': 3},
#  'places': {},
#  'things': {u'time - turner': 1},
#  'times': {},
#  'verbs': {u'be': 1,
#            u'claim': 1,
#            u'demand': 1,
#            u'go': 1,
#            u'have': 1,
#            u'hear': 1,
#            u'intervene': 1,
#            u'listen': 1,
#            u'refuse': 1,
#            u'save': 1,
#            u'visit': 1}}
# {'people': {u'albus': 2, u'harry': 3, u'hogwarts': 1, u'lily': 1},
#  'places': {u'albus': 1},
#  'things': {},
#  'times': {},
#  'verbs': {u'be': 1,
#            u'change': 1,
#            u'express': 1,
#            u'give': 1,
#            u'happen': 1,
#            u'lead': 1,
#            u'leave': 1,
#            u'make': 1,
#            u'mend': 1,
#            u'receive': 1,
#            u'regret': 1,
#            u'reject': 1,
#            u'relate': 1,
#            u'say': 1,
#            u'speak': 1,
#            u'strain': 1,
#            u'take': 1,
#            u'try': 1}}
# {'people': {u'ginny': 1, u'harry': 3, u'hermione': 1},
#  'places': {},
#  'things': {u'voldemort': 1},
#  'times': {},
#  'verbs': {u'ask': 1,
#            u'be': 2,
#            u'begin': 1,
#            u'comfort': 1,
#            u'concern': 1,
#            u'decide': 1,
#            u'experience': 2,
#            u'explain': 1,
#            u'hurt': 1,
#            u'know': 1,
#            u'leave': 1,
#            u'let': 1,
#            u'proceed': 1,
#            u'take': 1,
#            u'try': 1}}
# {'people': {u'albus': 1,
#             u'amos': 1,
#             u'cedric': 1,
#             u'draco': 3,
#             u'ginny': 2,
#             u'harry': 4,
#             u'hermione': 1,
#             u'scorpius': 1},
#  'places': {},
#  'things': {u'albus': 1, u'draco': 1, u'scorpius': 1, u'time - turner': 1},
#  'times': {},
#  'verbs': {u'accuse': 1,
#            u'be': 7,
#            u'conclude': 1,
#            u'decide': 1,
#            u'get': 1,
#            u'go': 1,
#            u'help': 1,
#            u'hold': 1,
#            u'interrupt': 1,
#            u'learn': 1,
#            u'proceed': 1,
#            u'prompt': 1,
#            u'pull': 1,
#            u'retrieve': 1,
#            u'run': 1,
#            u'save': 1,
#            u'start': 1,
#            u'storm': 1,
#            u'want': 1}}
# {'people': {u'albus': 3,
#             u'bane': 2,
#             u'ginny': 1,
#             u'harry': 2,
#             u'ron': 1,
#             u'scorpius': 3},
#  'places': {u'forbidden': 1},
#  'things': {u'albus': 1},
#  'times': {},
#  'verbs': {u'be': 2,
#            u'come': 1,
#            u'create': 1,
#            u'find': 1,
#            u'haunt': 1,
#            u'have': 1,
#            u'mean': 1,
#            u'receive': 1,
#            u'regard': 1,
#            u'return': 1,
#            u'reveal': 1,
#            u'search': 1,
#            u'strengthen': 1,
#            u'sustain': 1,
#            u'take': 1,
#            u'travel': 1,
#            u'warn': 1}}
# {'people': {u'albus': 2, u'dumdledore': 1, u'harry': 5, u'scorpius': 1},
#  'places': {},
#  'things': {u'albus': 1,
#             u'albus dumbledore': 1,
#             u'headmistress    minerva mcgonagall': 1,
#             u'marauder': 1},
#  'times': {u'decade': 1},
#  'verbs': {u'advise': 1,
#            u'air': 1,
#            u'be': 4,
#            u'blind': 1,
#            u'break': 1,
#            u'bring': 1,
#            u'bully': 1,
#            u'converse': 1,
#            u'demand': 1,
#            u'do': 2,
#            u'go': 1,
#            u'intensify': 1,
#            u'keep': 1,
#            u'leave': 1,
#            u'reassure': 1,
#            u'see': 1,
#            u'use': 1}}
# {'people': {u'draco': 2, u'ginny': 2, u'harry': 3},
#  'places': {u'albus': 1, u'hogwarts': 1, u'scorpius': 1},
#  'things': {},
#  'times': {},
#  'verbs': {u'argue': 1,
#            u'be': 2,
#            u'explain': 1,
#            u'go': 1,
#            u'have': 1,
#            u'intervene': 1,
#            u'miss': 1,
#            u'receive': 1,
#            u'remind': 1,
#            u'result': 1,
#            u'surprise': 1,
#            u'travel': 1}}
# {'people': {u'albus': 1,
#             u'draco': 2,
#             u'harry': 3,
#             u'mcgonagall': 1,
#             u'scorpius': 1},
#  'places': {u'hogwarts': 1},
#  'things': {u'time - turner': 1},
#  'times': {},
#  'verbs': {u'apologise': 1,
#            u'attempt': 1,
#            u'discover': 1,
#            u'gain': 1,
#            u'have': 1,
#            u'isolate': 1,
#            u'locate': 1,
#            u'look': 1,
#            u'make': 1,
#            u'realise': 1,
#            u'return': 1,
#            u'speak': 1}}
# {'people': {u'albus': 4, u'harry': 3, u'scorpius': 2},
#  'places': {},
#  'things': {u'hogwarts': 1},
#  'times': {},
#  'verbs': {u'create': 1,
#            u'die': 1,
#            u'manage': 2,
#            u'plant': 1,
#            u'return': 1,
#            u'salvage': 1,
#            u'visit': 1}}
# {'people': {u'albus': 1, u'amos': 1, u'harry': 1, u'scorpius': 1},
#  'places': {},
#  'things': {u'delphi': 2},
#  'times': {},
#  'verbs': {u'be': 1,
#            u'believe': 1,
#            u'confund': 1,
#            u'find': 2,
#            u'go': 1,
#            u'know': 1,
#            u'learn': 1,
#            u'miss': 1,
#            u'see': 2}}
# {'people': {u'bellatrix lestrange': 1},
#  'places': {u'voldemort': 1},
#  'things': {u'albus': 1, u'delphi': 3, u'scorpius': 1, u'voldemort': 1},
#  'times': {},
#  'verbs': {u'be': 1,
#            u'bide': 1,
#            u'enable': 1,
#            u'find': 1,
#            u'fulfil': 1,
#            u'know': 1,
#            u'realise': 1,
#            u'search': 1,
#            u'stumble': 1,
#            u'wait': 1}}
# {'people': {u'draco': 1, u'ginny': 1, u'harry': 2, u'hermione': 1, u'ron': 1},
#  'places': {},
#  'things': {u'albus': 2, u'time - turner': 1, u'voldemort': 1},
#  'times': {u'30 october 1981': 1, u'night': 1, u'one day': 1},
#  'verbs': {u'alert': 1,
#            u'be': 4,
#            u'find': 1,
#            u'give': 1,
#            u'have': 1,
#            u'join': 1,
#            u'kill': 1,
#            u'look': 1,
#            u'notice': 2,
#            u'reveal': 1,
#            u'seize': 1,
#            u'send': 1,
#            u'try': 1}}
# {'people': {u'harry': 1},
#  'places': {u'albus': 1, u'scorpius': 1, u'voldemort': 1},
#  'things': {u'delphi': 2, u'ginny': 1},
#  'times': {},
#  'verbs': {u'continue': 1,
#            u'do': 1,
#            u'join': 1,
#            u'kill': 1,
#            u'know': 1,
#            u'lead': 1,
#            u'live': 1,
#            u'love': 1,
#            u'make': 1,
#            u'meet': 1,
#            u'realise': 1,
#            u'stop': 1,
#            u'travel': 1,
#            u'want': 1}}
# {'people': {u'harry': 2},
#  'places': {u'horcrux': 1, u'voldemort': 3},
#  'things': {u'delphi': 1},
#  'times': {},
#  'verbs': {u'agree': 1,
#            u'be': 1,
#            u'fool': 1,
#            u'have': 1,
#            u'hinder': 1,
#            u'know': 1,
#            u'look': 1,
#            u'pick': 1,
#            u'save': 1,
#            u'share': 1,
#            u'transfigure': 1,
#            u'understand': 1}}
# {'people': {u'albus': 1, u'harry': 3},
#  'places': {},
#  'things': {u'delphi': 2},
#  'times': {},
#  'verbs': {u'be': 1,
#            u'change': 1,
#            u'come': 1,
#            u'engage': 1,
#            u'explain': 1,
#            u'join': 1,
#            u'know': 1,
#            u'manage': 2,
#            u'plead': 2,
#            u'recognise': 1,
#            u'see': 1,
#            u'set': 1,
#            u'subdue': 1,
#            u'want': 1}}
# {'people': {u'albus': 1,
#             u'dursleys': 1,
#             u'harry': 3,
#             u'hermione': 1,
#             u'malfoy': 1},
#  'places': {u'voldemort': 1},
#  'things': {u'delphi': 1},
#  'times': {},
#  'verbs': {u'arrive': 2,
#            u'bring': 1,
#            u'call': 1,
#            u'decide': 1,
#            u'hear': 1,
#            u'kill': 1,
#            u'provide': 1,
#            u'return': 1,
#            u'send': 1,
#            u'silence': 1,
#            u'try': 1,
#            u'watch': 1}}
# {'people': {u'albus': 1, u"cedric diggory 's": 1, u'harry': 2},
#  'places': {u'albus': 1, u'hogwarts': 1},
#  'things': {},
#  'times': {},
#  'verbs': {u'apologise': 1,
#            u'ask': 1,
#            u'bring': 1,
#            u'join': 1,
#            u'reveal': 1,
#            u'visit': 1}}
